# %%
# %matplotlib inline
exec "l=" + open("pypy-warm-hacks.dat").read()
exec "l2=" + open("pypy-cold-hacks.dat").read()

# %%
from matplotlib import pyplot as plt
plt.figure(figsize=(15, 10))
plt.plot(l)
plt.plot(l2)

# %%
_ = plt.hist(l, bins=20)
_ = plt.hist(l2, bins=20)
print "%.1fms" % (max(l) * 1000), "%1.fms" % (max(l2) * 1000)
# Out:
# 96.3ms 135ms
